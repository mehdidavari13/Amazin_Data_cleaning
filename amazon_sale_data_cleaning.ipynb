# %% [markdown]
# Amazon sale report data cleaning project

# %% [markdown]
# Libraries that I work with:

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import calendar 
sns.set(style="darkgrid")

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# Opening file and check top rows of Dataframe

# %%
amazon=pd.read_csv(r'Dataset\Amazon Sale Report.csv', low_memory=False)
amazon.head(7)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
# 5      5  404-1490984-4578765  04-30-22                       Shipped
# 6      6  408-5748499-6859555  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# ...

# %% [markdown]
# check shape of Dataframe

# %%
amazon.shape
# Out:
# (128975, 24)

# %% [markdown]
# Checking the data type of each column and the non-null number of values in each column

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %% [markdown]
# Creating a list of dataframe column names and strip string values

# %%
columns = list(amazon.columns)
columns
# Out:
# ['index',
#  'Order ID',
#  'Date',
#  'Status',
#  'Fulfilment',
#  'Sales Channel ',
#  'ship-service-level',
#  'Style',
#  'SKU',
#  'Category',
#  'Size',
#  'ASIN',
#  'Courier Status',
#  'Qty',
#  'currency',
#  'Amount',
#  'ship-city',
#  'ship-state',
#  'ship-postal-code',
#  'ship-country',
#  'promotion-ids',
#  'B2B',
#  'fulfilled-by',
#  'Unnamed: 22']

# %%
string_columns = list(amazon.columns)
string_columns.remove('index')
string_columns.remove('Qty')
string_columns.remove('Amount')
string_columns.remove('ship-postal-code')
string_columns.remove('B2B')
string_columns.remove('Unnamed: 22')
for i in string_columns:
    amazon[i]=amazon[i].str.strip()
print('done')
# Out:
# done

# %% [markdown]
# Missing values distribution

# %%
print ("Missing values distribution:")
print (amazon.isnull().mean())
# Out:
# Missing values distribution:
# index                 0.000000
# Order ID              0.000000
# Date                  0.000000
# Status                0.000000
# Fulfilment            0.000000
# Sales Channel         0.000000
# ship-service-level    0.000000
# Style                 0.000000
# SKU                   0.000000
# Category              0.000000
# Size                  0.000000
# ASIN                  0.000000
# Courier Status        0.053282
# Qty                   0.000000
# currency              0.060438
# Amount                0.060438
# ship-city             0.000256
# ship-state            0.000256
# ship-postal-code      0.000256
# ship-country          0.000256
# promotion-ids         0.381105
# B2B                   0.000000
# fulfilled-by          0.695468
# Unnamed: 22           0.380306
# dtype: float64

# %%
amazon.describe().T
# Out:
#                      count           mean            std       min       25%  \
# index             128975.0   64487.000000   37232.019822       0.0   32243.5
# Qty               128975.0       0.904431       0.313354       0.0       1.0
# Amount            121180.0     648.561465     281.211687       0.0     449.0
# ship-postal-code  128942.0  463966.236509  191476.764941  110001.0  382421.0
#
#                        50%       75%       max
# index              64487.0   96730.5  128974.0
# Qty                    1.0       1.0      15.0
# Amount               605.0     788.0    5584.0
# ship-postal-code  500033.0  600024.0  989898.0

# %%
amazon.describe(include='all')
# Out:
#                 index             Order ID      Date   Status Fulfilment  \
# count   128975.000000               128975    128975   128975     128975
# unique            NaN               120378        91       13          2
# top               NaN  171-5057375-2831560  05-03-22  Shipped     Amazon
# freq              NaN                   12      2085    77804      89698
# mean     64487.000000                  NaN       NaN      NaN        NaN
# std      37232.019822                  NaN       NaN      NaN        NaN
# min          0.000000                  NaN       NaN      NaN        NaN
# 25%      32243.500000                  NaN       NaN      NaN        NaN
# 50%      64487.000000                  NaN       NaN      NaN        NaN
# 75%      96730.500000                  NaN       NaN      NaN        NaN
# max     128974.000000                  NaN       NaN      NaN        NaN
#
#        Sales Channel  ship-service-level    Style           SKU Category  \
# ...

# %%
sns.heatmap(amazon.isnull())
plt.show()

# %% [markdown]
# Drop columns

# %%
amazon.drop(['index','fulfilled-by','Unnamed: 22'] , axis = 1 , inplace = True)
print('done')
# Out:
# done

# %% [markdown]
# checking for duplicate rows

# %%
amazon.nunique().to_frame(name='Count of unique values')
# Out:
#                     Count of unique values
# Order ID                            120378
# Date                                    91
# Status                                  13
# Fulfilment                               2
# Sales Channel                            2
# ship-service-level                       2
# Style                                 1377
# SKU                                   7195
# Category                                 9
# Size                                    11
# ASIN                                  7190
# Courier Status                           3
# Qty                                     10
# currency                                 1
# Amount                                1410
# ship-city                             8955
# ship-state                              69
# ship-postal-code                      9459
# ship-country                             1
# promotion-ids                         5787
# B2B                                      2

# %% [markdown]
# Drop duplicate Rows

# %%
amazon[amazon.duplicated(['Order ID','ASIN'], keep=False)]
# Out:
#                   Order ID      Date     Status Fulfilment Sales Channel   \
# 30660  406-0372545-6086735  04-12-22  Cancelled     Amazon      Amazon.in
# 30661  406-0372545-6086735  04-12-22  Cancelled     Amazon      Amazon.in
# 41291  408-0373839-4433120  04-05-22  Cancelled     Amazon      Amazon.in
# 41292  408-0373839-4433120  04-05-22  Cancelled     Amazon      Amazon.in
# 52330  407-8364731-6449117  05-29-22    Shipped     Amazon      Amazon.in
# 52333  407-8364731-6449117  05-29-22    Shipped     Amazon      Amazon.in
# 79844  171-9628368-5329958  05-07-22  Cancelled     Amazon      Amazon.in
# 79845  171-9628368-5329958  05-07-22  Cancelled     Amazon      Amazon.in
# 85790  171-3249942-2207542  05-03-22    Shipped     Amazon      Amazon.in
# 85791  171-3249942-2207542  05-03-22    Shipped     Amazon      Amazon.in
# 86418  405-8669298-3850736  05-03-22    Shipped     Amazon      Amazon.in
# 86419  405-8669298-3850736  05-03-22    Shipped     Amazon      Amazon.in
# ...

# %%
len(amazon)-len(amazon.drop_duplicates(['Order ID','ASIN']))
# Out:
# 7

# %%
amazon.drop_duplicates(['Order ID','ASIN'],inplace = True,ignore_index=True)

# %% [markdown]
# fill  NaN cell

# %%
amazon['Courier Status'].fillna('unknown',inplace=True)
amazon['ship-city'].fillna('unknown',inplace=True)
amazon['ship-country'].fillna('unknown',inplace=True)
amazon['ship-state'].fillna('unknown',inplace=True)
amazon['promotion-ids'].fillna('no promotion',inplace=True)
amazon['ship-postal-code'].fillna('unknown',inplace=True)

# %%
amazon[amazon['Amount'].isnull()]['Status'].value_counts(normalize=True).apply(lambda x: format(x, '.3%'))
# Out:
# Cancelled                       97.061%
# Shipped                          2.669%
# Shipped - Delivered to Buyer     0.103%
# Shipping                         0.103%
# Shipped - Returned to Seller     0.039%
# Pending                          0.026%
# Name: Status, dtype: object

# %%
amazon['Amount'].fillna( 0 , inplace=True)
amazon['currency'].fillna("INR" , inplace=True)

# %%
amazon.isna().sum()
# Out:
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Style                 0
# SKU                   0
# Category              0
# Size                  0
# ASIN                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# promotion-ids         0
# B2B                   0
# dtype: int64

# %%
amazon['Status'].value_counts(dropna=False)
# Out:
# Shipped                          77800
# Shipped - Delivered to Buyer     28769
# Cancelled                        18329
# Shipped - Returned to Seller      1953
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: Status, dtype: int64

# %%
amazon.head(10)
# Out:
#               Order ID      Date                        Status Fulfilment  \
# 0  405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3  403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4  407-1069790-7240320  04-30-22                       Shipped     Amazon
# 5  404-1490984-4578765  04-30-22                       Shipped     Amazon
# 6  408-5748499-6859555  04-30-22                       Shipped     Amazon
# 7  406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer   Merchant
# 8  407-5443024-5233168  04-30-22                     Cancelled     Amazon
# 9  402-4393761-0311520  04-30-22                       Shipped     Amazon
#
#   Sales Channel  ship-service-level    Style                  SKU  \
# 0      Amazon.in           Standard   SET389       SET389-KR-NP-S
# ...

# %% [markdown]
# change B2B column name  to customer_type and convert value

# %%
amazon.rename(columns= {'B2B': 'customer_type'}, inplace=True)
amazon['customer_type'].replace(to_replace=[True,False], value=['Bussines','Customer'], inplace=True)

# %%
amazon['Date'].value_counts()
# Out:
# 05-03-22    2083
# 05-02-22    2079
# 05-04-22    2015
# 04-14-22    1883
# 04-15-22    1853
#             ...
# 06-23-22    1090
# 06-24-22    1028
# 06-25-22    1026
# 06-29-22     658
# 03-31-22     171
# Name: Date, Length: 91, dtype: int64

# %% [markdown]
# insert Mount column

# %%
month = []
for i in range(len(amazon)):
        date = amazon['Date'].iloc[i].split('-')
        month.append(date[0])
for i , month1 in enumerate(month):
    if month != 0:
        month[i] = calendar.month_name[int(month1)]
amazon.insert(2,'Month',month, allow_duplicates=True)

# %%
amazon.head(7)
# Out:
#               Order ID      Date  Month                        Status  \
# 0  405-8078784-5731545  04-30-22  April                     Cancelled
# 1  171-9198151-1101146  04-30-22  April  Shipped - Delivered to Buyer
# 2  404-0687676-7273146  04-30-22  April                       Shipped
# 3  403-9615377-8133951  04-30-22  April                     Cancelled
# 4  407-1069790-7240320  04-30-22  April                       Shipped
# 5  404-1490984-4578765  04-30-22  April                       Shipped
# 6  408-5748499-6859555  04-30-22  April                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# ...
